# %% [markdown]
# # My First Data Science Notebook
# ## Introduction
# Xin chào! Tôi là Bùi Minh Thư

# %%
print("Hello, Data Science World!")
# Out:
# Hello, Data Science World!

# %% [markdown]
# ### 5 Thư viện Python phổ biến trong Data Science:
# * **NumPy**: Tính toán số học và xử lý mảng.
# * **Pandas**: Phân tích và thao tác dữ liệu.
# * **Matplotlib**: Vẽ biểu đồ tĩnh.
# * **Scikit-learn**: Các thuật toán học máy (Machine Learning).
# * **Seaborn**: Trực quan hóa dữ liệu thống kê.

# %%
import numpy as np

# Tạo một mảng đơn giản
my_array = np.array([1, 2, 3, 4, 5])

# %%
# Tính và hiển thị giá trị trung bình
mean_value = np.mean(my_array)
print(f"Giá trị trung bình của mảng là: {mean_value}")
# Out:
# Giá trị trung bình của mảng là: 3.0
